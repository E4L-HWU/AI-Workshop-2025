# %% [markdown]
# ## Install required libraries if needed and check GPU

# %%
# !pip install ultralytics #install ultralytics frame-work
# !pip install roboflow #install roboflow for dataset retrival
# !nvidia-smi #check GPU is running (won't work for CPU)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 kB 20.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 95.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 79.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 48.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 38.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 17.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 94.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %% [markdown]
# ## import needed libraries

# %%
from ultralytics import YOLO #import YOLO from ultralytics
from roboflow import Roboflow #import Roboflow from roboflow
# !yolo checks # check YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.71 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (NVIDIA L4, 22693MiB)
# Setup complete ✅ (12 CPUs, 53.0 GB RAM, 33.1/235.7 GB disk)
#
# OS                  Linux-6.1.85+-x86_64-with-glibc2.35
# Environment         Colab
# Python              3.11.11
# Install             pip
# RAM                 52.96 GB
# Disk                33.1/235.7 GB
# CPU                 Intel Xeon 2.20GHz
# CPU count           12
# GPU                 NVIDIA L4, 22693MiB
# GPU count           1
# CUDA                12.4
#
# numpy               ✅ 1.26.4<=2.1.1,>=1.23.0
# matplotlib          ✅ 3.10.0>=3.3.0
# opencv-python       ✅ 4.10.0.84>=4.6.0
# pillow              ✅ 11.1.0>=7.1.2
# ...

# %% [markdown]
# ## get data set

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="dIsW3kVkLniPwRk3xZFV")
project = rf.workspace("whowho").project("rockets-rockets")
version = project.version(9)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to RockETS-Rockets-9 in yolov8:: 100%|██████████| 2848/2848 [00:00<00:00, 4560.49it/s]

# %% [markdown]
# # Train

# %%
# Load the YOLOv8 segmentation model
model = YOLO("yolov8s.pt")

# Train the model with detailed parameters
results = model.train(
    data="/content/RockETS-Rockets-9/data.yaml",  # Path / string
    epochs=20,                      # int
    batch=16,                       # int
    imgsz=164,                      # int
    lr0=0.01,                       # int
    optimizer='SGD',               # 'SGD', 'Adam', 'AdamW'
    augment=False,                   # True, False
    pretrained=True                 # True, False
)
# Out:
# ...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 200MB/s]
# Ultralytics 8.3.71 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (NVIDIA L4, 22693MiB)
# ...
